# %%
from datetime import datetime
import pytz

# %%
current_timestamp = datetime.now() # current date and time
print("Current Timestamp:", current_timestamp)
# Out:
# Current Timestamp: 2025-10-07 22:03:39.463865

# %%
print("Current Year:", current_timestamp.year)
# Out:
# Current Year: 2025

# %%
print("Current Month:", current_timestamp.month)
# Out:
# Current Month: 10

# %%
print("Current Year-Month-Day:", current_timestamp.date())
# Out:
# Current Year-Month-Day: 2025-10-07

# %%
pytz.timezone("Asia/Kolkata").localize(current_timestamp)
# Out:
# datetime.datetime(2025, 10, 7, 22, 3, 39, 463865, tzinfo=<DstTzInfo 'Asia/Kolkata' IST+5:30:00 STD>)

# %%
datetime.now(pytz.timezone('Asia/Kolkata'))
# Out:
# datetime.datetime(2025, 10, 7, 22, 14, 13, 762016, tzinfo=<DstTzInfo 'Asia/Kolkata' IST+5:30:00 STD>)

# %%
datetime.utcnow()
# Out:
# /tmp/ipykernel_278789/3983769260.py:1: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   datetime.utcnow()
# datetime.datetime(2025, 10, 7, 16, 35, 58, 874427)

# %%
datetime.now()
# Out:
# datetime.datetime(2025, 10, 7, 22, 9, 2, 24964)
