# %%
import pathlib

# %%
index_dir = "./vector_index"

# %%
p = pathlib.Path(index_dir).resolve().parent

# %%
p
# Out:
# PosixPath('/home/farheens/Desktop/Order_Management_System/notebooks')

# %%
p.mkdir(parents=True,exist_ok=True)

# %%
import sys

# %%
sys.stdout

# %%
sys.stderr

# %%
from streamlit_cookies_manager import EncryptedCookieManager
# Out:
# 2025-10-03 12:46:36.167 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 12:46:36.173 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 12:46:36.213
# ...
#   command:
#
#     streamlit run /home/farheens/anaconda3/envs/ai_agent/lib/python3.13/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-10-03 12:46:36.214 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 12:46:36.215 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 12:46:36.215
# `st.cache` is deprecated and will be removed soon. Please use one of Streamlit's new
# caching commands, `st.cache_data` or `st.cache_resource`. More information
# [in our docs](https://docs.streamlit.io/develop/concepts/architecture/caching).
#
# ...

# %%
EncryptedCookieManager()
# Out:
# Help on class EncryptedCookieManager in module streamlit_cookies_manager.encrypted_cookie_manager:
#
# class EncryptedCookieManager(collections.abc.MutableMapping, typing.Generic)
#  |  EncryptedCookieManager(
#  |      *,
#  |      password: str,
#  |      path: str = None,
#  |      prefix: str = '',
#  |      key_params_cookie='EncryptedCookieManager.key_params',
#  |      ignore_broken=True
#  |  )
#  |
#  |  Method resolution order:
#  |      EncryptedCookieManager
#  |      collections.abc.MutableMapping
#  |      collections.abc.Mapping
#  |      collections.abc.Collection
#  |      collections.abc.Sized
#  |      collections.abc.Iterable
#  |      collections.abc.Container
#  |      typing.Generic
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __delitem__(self, key: str) -> None
#  |
#  |  __getitem__(self, k: str) -> str
#  |
#  |  __init__(
#  |      self,
#  |      *,
#  |      password: str,
#  |      path: str = None,
#  |      prefix: str = '',
# ...
